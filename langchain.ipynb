# %%
from openai import OpenAI
from langchain.chat_models import ChatOpenAI

llm = ChatOpenAI()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from openai import OpenAI
#       2 from langchain.chat_models import ChatOpenAI
#       4 llm = ChatOpenAI()
#
# ModuleNotFoundError: No module named 'openai'

# %%
llm.invoke("how can langsmith help with testing?")
# Out:
# AIMessage(content="Langsmith can help with testing in several ways:\n\n1. Automated Testing: Langsmith can generate test cases and automate the execution of test scripts. It can generate various inputs and expected outputs based on the given language specifications. This can significantly speed up the testing process and ensure comprehensive test coverage.\n\n2. Test Oracles: Langsmith can generate test oracles, which are mechanisms to determine the correctness of the output for a given input. It can compare the expected output generated by the language specification with the actual output of the program being tested. This helps in identifying any deviations or errors.\n\n3. Test Data Generation: Langsmith can generate diverse and comprehensive test data for different scenarios. It can create inputs that cover a wide range of possibilities, including edge cases and corner cases. This ensures that the software being tested is robust and handles various inputs effectively.\n\n4. Test Suite Generation: Langsmith can generate a suite of test cases based on the language specifications. It can create a set of test cases that cover different aspects of the language, such as syntax, semantics, and error handling. This helps in systematically testing the language implementation and identifying any issues or inconsistencies.\n\n5. Regression Testing: Langsmith can assist in regression testing, which involves retesting the software after changes or modifications are made. It can automatically update the test suite based on the updated language specifications and rerun the tests to ensure that the changes have not introduced any regressions or new errors.\n\nOverall, Langsmith's capabilities in test case generation, test oracle creation, test data generation, test suite generation, and regression testing can help streamline and improve the testing process, ensuring the reliability and correctness of the software being tested.")

# %%
from langchain.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are world class technical documentation writer."),
    ("user", "{input}")
])

# %%
from langchain_core.output_parsers import StrOutputParser

output_parser = StrOutputParser()

# %%
chain = prompt | llm | output_parser

# %%
chain.invoke({"input": "how can langsmith help with testing?"})
# Out:
# 'Langsmith can greatly assist with testing by providing various features and tools that streamline the testing process. Here are a few ways in which Langsmith can help:\n\n1. Test Case Management: Langsmith provides a centralized repository to manage test cases, making it easier to organize and track testing activities. Test cases can be created, updated, and linked to specific requirements, allowing for better traceability.\n\n2. Test Execution: Langsmith enables the execution of test cases and the recording of test results. Testers can record their observations, attach screenshots, and log any defects encountered during testing. This helps in capturing and documenting test evidence.\n\n3. Test Automation: Langsmith supports test automation frameworks, allowing testers to automate repetitive test cases. This not only saves time but also improves accuracy and consistency in test execution. Test scripts can be easily created and executed within the Langsmith environment.\n\n4. Defect Tracking: Langsmith facilitates the tracking and management of defects found during testing. Testers can log defects directly within the tool, providing all the necessary details such as steps to reproduce, expected behavior, and severity. Defects can then be assigned, tracked, and resolved efficiently.\n\n5. Collaboration: Langsmith fosters collaboration among testing teams by providing features for sharing test cases, test results, and defect information. Team members can collaborate in real-time, ensuring everyone is on the same page and can contribute to the testing effort effectively.\n\n6. Reporting and Analytics: Langsmith offers customizable reporting capabilities, allowing testers to generate test execution reports, defect reports, and other metrics. These reports provide insights into the testing progress, test coverage, and overall quality of the software under test.\n\nOverall, Langsmith streamlines testing activities, improves efficiency, and enhances collaboration among testing teams. It helps ensure that testing is well-documented, organized, and allows for better traceability, leading to higher quality software.'

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("./index.md")
document = loader.load()

# %%
from langchain_community.document_loaders import WebBaseLoader
loader = WebBaseLoader("https://docs.smith.langchain.com/overview")

docs = loader.load()

# %%
from langchain_community.embeddings import OpenAIEmbeddings

embeddings = OpenAIEmbeddings()

# %%
from langchain_community.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter


text_splitter = RecursiveCharacterTextSplitter()
documents = text_splitter.split_documents(docs)
vector = FAISS.from_documents(documents, embeddings)

# %%
from langchain.chains.combine_documents import create_stuff_documents_chain

prompt = ChatPromptTemplate.from_template("""Answer the following question based only on the provided context:

<context>
{context}
</context>

Question: {input}""")

document_chain = create_stuff_documents_chain(llm, prompt)

# %%
from langchain.chains import create_retrieval_chain

retriever = vector.as_retriever()
retrieval_chain = create_retrieval_chain(retriever, document_chain)

# %%
response = retrieval_chain.invoke({"input": "how can langsmith help with testing?"})
print(response["answer"])

# LangSmith offers several features that can help with testing:...
# Out:
# LangSmith can help with testing by simplifying the process of dataset uploading and running chains over the data points. It allows users to pull down a dataset and run a chain over them, logging the results to a new project associated with the dataset. Users can review the results, assign feedback to runs, and mark them as correct or incorrect. LangSmith also provides evaluators to guide users to examples they should look at, especially when the number of data points becomes too large to manually review each one. Additionally, LangSmith offers annotation queues that allow users to manually review and annotate runs, particularly for assessing subjective qualities or validating auto-evaluated runs.
